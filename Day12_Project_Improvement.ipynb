# %%
# Sales Data Analysis Dashboard

## Project Improvement

This notebook presents an improved version of the Sales Data Analysis Dashboard with better formatting, comments, code readability, and visual presentation.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd

df = pd.read_csv("cleaned_sales_data.csv")

# %%
# Display the first five rows
df.head()

# Display dataset information
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      10 non-null     str
#  1   Product   10 non-null     str
#  2   Category  10 non-null     str
#  3   Quantity  10 non-null     int64
#  4   Sales     10 non-null     int64
#  5   Profit    10 non-null     int64
# dtypes: int64(3), str(3)
# memory usage: 612.0 bytes

# %%
product_sales = df.groupby("Product")["Sales"].sum()

plt.figure(figsize=(8,5))

product_sales.plot(kind="bar")

plt.title("Product-wise Sales")
plt.xlabel("Product")
plt.ylabel("Sales")

plt.xticks(rotation=45)

plt.grid(axis="y")

plt.show()

# %%
print("="*40)
print(" SALES DASHBOARD ")
print("="*40)

print("Total Sales :", df["Sales"].sum())
print("Average Sales :", round(df["Sales"].mean(),2))
print("Maximum Sales :", df["Sales"].max())
print("Minimum Sales :", df["Sales"].min())
# Out:
# ...
#  SALES DASHBOARD
# ...
# Total Sales : 425000
# Average Sales : 42500.0
# Maximum Sales : 65000
# Minimum Sales : 18000
