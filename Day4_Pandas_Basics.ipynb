# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.0 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/10.0 MB 2.7 MB/s eta 0:00:04
#    ------ --------------------------------- 1.6/10.0 MB 2.6 MB/s eta 0:00:04
#    -------- ------------------------------- 2.1/10.0 MB 2.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.6/10.0 MB 2.6 MB/s eta 0:00:03
#    ------------- -------------------------- 3.4/10.0 MB 2.7 MB/s eta 0:00:03
#    -------------- ------------------------- 3.7/10.0 MB 2.6 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.5/10.0 MB 2.6 MB/s eta 0:00:03
#    -------------------- ------------------- 5.0/10.0 MB 2.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.5/10.0 MB 2.6 MB/s eta 0:00:02
# ...

# %%
import pandas as pd

# %%
import pandas as pd

series = pd.Series([10, 20, 30, 40, 50])

print(series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
import pandas as pd

data = {
    "Name": ["Nithya", "Rahul", "Anu"],
    "Age": [21, 22, 20],
    "City": ["Palakkad", "Kochi", "Thrissur"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#      Name  Age      City
# 0  Nithya   21  Palakkad
# 1   Rahul   22     Kochi
# 2     Anu   20  Thrissur

# %%
print(df.head())
print(df.tail())
# Out:
#      Name  Age      City
# 0  Nithya   21  Palakkad
# 1   Rahul   22     Kochi
# 2     Anu   20  Thrissur
#      Name  Age      City
# 0  Nithya   21  Palakkad
# 1   Rahul   22     Kochi
# 2     Anu   20  Thrissur

# %%
print(df["Name"])
# Out:
# 0    Nithya
# 1     Rahul
# 2       Anu
# Name: Name, dtype: str

# %%
print(df.loc[0])
print(df.iloc[1])
# Out:
# Name      Nithya
# Age           21
# City    Palakkad
# Name: 0, dtype: object
# Name    Rahul
# Age        22
# City    Kochi
# Name: 1, dtype: object

# %%
df.to_csv("students.csv", index=False)

# %%
new_df = pd.read_csv("students.csv")
print(new_df)
# Out:
#      Name  Age      City
# 0  Nithya   21  Palakkad
# 1   Rahul   22     Kochi
# 2     Anu   20  Thrissur

# %%
import pandas as pd

student = {
    "Name": ["Arun", "Nithya", "Meera"],
    "Marks": [90, 95, 88],
    "Department": ["CSE", "CSE", "ECE"]
}

df = pd.DataFrame(student)

print(df)
print(df.describe())
print(df["Marks"])
# Out:
#      Name  Marks Department
# 0    Arun     90        CSE
# 1  Nithya     95        CSE
# 2   Meera     88        ECE
#            Marks
# count   3.000000
# mean   91.000000
# std     3.605551
# min    88.000000
# 25%    89.000000
# 50%    90.000000
# 75%    92.500000
# max    95.000000
# 0    90
# 1    95
# 2    88
# Name: Marks, dtype: int64
