# %%
print("Hello, Codomax!")
print("My name is Nithya.")
print("This is my first Data Science Internship Task.")
# Out:
# Hello, Codomax!
# My name is Nithya.
# This is my first Data Science Internship Task.
